# %%
import pandas as pd 
pd.read_csv("C:/Users/arvin/Downloads/problem_with_a_credit_reporting_company's_investigation_into_an_existing_problem.csv")
# Out:
#                                                Topic  \
# 0  problem_with_a_credit_reporting_company's_inve...
# 1  problem_with_a_credit_reporting_company's_inve...
# 2  problem_with_a_credit_reporting_company's_inve...
# 3  problem_with_a_credit_reporting_company's_inve...
# 4  problem_with_a_credit_reporting_company's_inve...
# 5  problem_with_a_credit_reporting_company's_inve...
# 6  problem_with_a_credit_reporting_company's_inve...
# 7  problem_with_a_credit_reporting_company's_inve...
# 8  problem_with_a_credit_reporting_company's_inve...
# 9  problem_with_a_credit_reporting_company's_inve...
#
#                                            Question   \
# 0  Debt Collection: Can a creditor delete a repor...
# 1             What should I do as my w-2 was stolen?
# 2  What steps should my company begin to make to ...
# 3  What is the list of famous case studies taught...
# 4        Why are payday loan interest rates so high?
# 5  Why are the Feds not insisting the supervisor ...
# ...

# %%
pd.read_csv("C:/Users/arvin/Downloads/problem_with_fraud_alerts_or_security_freezes.csv")
# Out:
#                                            TOPIC  \
# 0  problem_with_fraud_alerts_or_security_freezes
# 1  problem_with_fraud_alerts_or_security_freezes
# 2  problem_with_fraud_alerts_or_security_freezes
# 3  problem_with_fraud_alerts_or_security_freezes
# 4  problem_with_fraud_alerts_or_security_freezes
# 5  problem_with_fraud_alerts_or_security_freezes
# 6  problem_with_fraud_alerts_or_security_freezes
# 7  problem_with_fraud_alerts_or_security_freezes
#
#                                             QUESTION  \
# 0  Identity: How do I find out if my Social Secur...
# 1                   What is good credit card advice?
# 2  Should I hesitate to use Equifax tools to free...
# 3  Is using credit cards or debit cards in India ...
# 4  How do you find a driver's license number if y...
# 5             What should I do as my w-2 was stolen?
# 6         How can I obtain a drivers license number?
# 7  My Social Security Number Was Stolen – Now Wha...
#
# ...

# %%
pd.read_csv("C:/Users/arvin/Downloads/settlement_process_and_costs.csv")
# Out:
#                          TOPIC   \
# 0  settlement_process_and_costs
# 1  settlement_process_and_costs
# 2  settlement_process_and_costs
# 3  settlement_process_and_costs
# 4  settlement_process_and_costs
# 5  settlement_process_and_costs
# 6  settlement_process_and_costs
#
#                                            QUESTION   \
# 0  What are current 7/11 customary closing & unde...
# 1    How could Blockchain technology change Finance?
# 2  What are some of the most intelligent crimes c...
# 3  How does an express (urgent) international wir...
# 4  If a person is in a big financial crisis, can ...
# 5  How does Claims Analytics impact the claims pr...
# 6       What benefits do banks gain by using Ripple?
#
#                                               ANSWER
# 0  No loan origination fees, und rewriting and pr...
# 1  The biggest problem banks have at this moment ...
# 2  I am amused that no one mentioned Mr Mithilesh...
# 3  On "URGENT", the sending bank may offer a late...
# ...

# %%
pd.read_csv("C:/Users/arvin/Downloads/struggling_to_pay_mortgage.csv")
# Out:
#                         TOPIC  \
# 0  struggling_to_pay_mortgage
# 1  struggling_to_pay_mortgage
# 2  struggling_to_pay_mortgage
# 3  struggling_to_pay_mortgage
# 4  struggling_to_pay_mortgage
# 5  struggling_to_pay_mortgage
# 6  struggling_to_pay_mortgage
# 7  struggling_to_pay_mortgage
# 8  struggling_to_pay_mortgage
# 9  struggling_to_pay_mortgage
#
#                                             QUESTION  \
# 0  I'm struggling to pay my mortgage. Can I lease...
# 1  If someone is working hard but struggling with...
# 2  I'm struggling with mortgage payment: one mont...
# 3  Does Donald Trump's ostentatious display of we...
# 4  What is it like to be in a relationship with s...
# 5  What is the biggest misconception Indians have...
# 6       When did you first realize you were wealthy?
# 7  With the rise in student loan debt and housing...
# 8  Students at IITs/BITS are getting a package of...
# 9  When will all the President Trump bashing slow...
#
# ...
